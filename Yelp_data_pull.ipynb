# %%
# -*- coding: utf-8 -*-
"""
Based on Yelp Fusion API code sample.

"""
from __future__ import print_function

import argparse
import json
import pprint
import requests
import sys
import urllib
import pandas as pd
from sqlalchemy import create_engine
engine = create_engine('sqlite://', echo=False)

# This client code can run on Python 2.x or 3.x.  Your imports can be
# simpler if you only need one of those.
try:
    # For Python 3.0 and later
    from urllib.error import HTTPError
    from urllib.parse import quote
    from urllib.parse import urlencode
except ImportError:
    # Fall back to Python 2's urllib2 and urllib
    from urllib2 import HTTPError
    from urllib import quote
    from urllib import urlencode

# %%
API_KEY= "tce8h_FqJw30vLO5EKIcuJ_hvnoHQ9H8D6408qWkwav4QkNo0lRLHLUQbG4hZtVafy4RStnjDP2R4HGv11-8S16bKaNCXDJ_1rdCzJZorapYft93jGU2r26S8pQrZHYx"


# API constants.
API_HOST = 'https://api.yelp.com'
#SEARCH_PATH = '/v3/categories'
SEARCH_PATH = '/v3/businesses/search'
BUSINESS_PATH = '/v3/businesses/'  # Business ID will come after slash.


# Defaults for our simple example.
#DEFAULT_TERM = 'dinner'
#DEFAULT_LOCATION = 'San Francisco, CA'
SEARCH_LIMIT = 50
#OFFSET = 950

# %%
def request(host, path, api_key, url_params=None):
    """Given your API_KEY, send a GET request to the API.

    Args:
        host (str): The domain host of the API.
        path (str): The path of the API after the domain.
        API_KEY (str): Your API Key.
        url_params (dict): An optional set of query parameters in the request.

    Returns:
        dict: The JSON response from the request.

    Raises:
        HTTPError: An error occurs from the HTTP request.
    """
    url_params = url_params or {}
    url = '{0}{1}'.format(host, quote(path.encode('utf8')))
    headers = {
        'Authorization': 'Bearer %s' % api_key,
    }

    print(u'Querying {0} ...'.format(url))

    response = requests.request('GET', url, headers=headers, params=url_params)

    return response.json()

# %%
def search(api_key, term, location, offset):
    """Query the Search API by a search term and location.

    Args:
        term (str): The search term passed to the API.
        location (str): The search location passed to the API.

    Returns:
        dict: The JSON response from the request.
    """

    url_params = {
        'term': term.replace(' ', '+'),
        'location': location.replace(' ', '+'),
        'offset':offset,
        'limit': SEARCH_LIMIT
    }
    return request(API_HOST, SEARCH_PATH, api_key, url_params=url_params)

# %%
search_categories =["mexican restaurants", "italian restaurants", "thai restaurants"]
restaurant_data = []
    
for search_category in search_categories:
    for j in range(20):
        offset = 50 * j
        restaurants = search(API_KEY,search_category, "Portland, OR", offset)
        x = len(restaurants['businesses'])
        for i in range(x):
            try:
                # Parse out name, review_count, categories, rating, price, latitude, longitude, city, state, country 
                restaurant_id = restaurants['businesses'][i]['id']
                restaurant_name = restaurants['businesses'][i]['name']
                restaurant_review_count = restaurants['businesses'][i]['review_count']
                categories = restaurants['businesses'][i]['categories']
                alias = [d.get('alias', None) for d in categories]
                if "italian" in alias:
                    restaurant_category = "Italian"
                elif "mexican" in alias:
                    restaurant_category = "Mexican"
                elif "thai" in alias:
                    restaurant_category = "Thai"
                else:
                    restaurant_category = "Other"
                restaurant_rating = restaurants['businesses'][i]['rating']
                restaurant_price = restaurants['businesses'][i]['price']
                restaurant_city = restaurants['businesses'][i]['location']['city']
                restaurant_country = restaurants['businesses'][i]['location']['country']
                restaurant_state = restaurants['businesses'][i]['location']['state']
                restaurant_lat = restaurants['businesses'][i]['coordinates']['latitude']
                restaurant_lng = restaurants['businesses'][i]['coordinates']['longitude']

                # Append the restaurant information into restaurant_data list
                restaurant_data.append({"id": restaurant_id,
                                        "name": restaurant_name,
                                        "review_count": restaurant_review_count,
                                        "category":restaurant_category,
                                        "rating": restaurant_rating,
                                        "price": restaurant_price,
                                        "city":restaurant_city,
                                        "state":restaurant_state,
                                        "country":restaurant_country,
                                        "Lat": restaurant_lat, 
                                        "Lng": restaurant_lng})  
            except:
                print("Skipping...")
                pass
            
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Querying https://api.yelp.com/v3/businesses/search ...
# Skipping...
# Skipping...
# Skipping...
# Skipping...
# Skipping...
# Skipping...
# Skipping...
# Skipping...
# Skipping...
# Skipping...
# Querying https://api.yelp.com/v3/businesses/search ...
# Skipping...
# Skipping...
# Skipping...
# Skipping...
# Skipping...
# Skipping...
# Skipping...
# Querying https://api.yelp.com/v3/businesses/search ...
# Skipping...
# Skipping...
# Skipping...
# Skipping...
# Skipping...
# Skipping...
# Skipping...
# Skipping...
# Skipping...
# Querying https://api.yelp.com/v3/businesses/search ...
# Skipping...
# Skipping...
# Skipping...
# Skipping...
# Skipping...
# Skipping...
# Skipping...
# Skipping...
# Skipping...
# Querying https://api.yelp.com/v3/businesses/search ...
# Skipping...
# Skipping...
# Skipping...
# Skipping...
# Skipping...
# Querying https://api.yelp.com/v3/businesses/search ...
# Skipping...
# Skipping...
# Skipping...
# Skipping...
# Skipping...
# Skipping...
# Skipping...
# Skipping...
# Querying https://api.yelp.com/v3/businesses/search ...
# Skipping...
# Skipping...
# Skipping...
# Skipping...
# Skipping...
# Skipping...
# Skipping...
# Skipping...
# Skipping...
# Skipping...
# Skipping...
# Querying https://api.yelp.com/v3/businesses/search ...
# Skipping...
# Skipping...
# Skipping...
# Skipping...
# Skipping...
# Skipping...
# Skipping...
# Skipping...
# Skipping...
# Querying https://api.yelp.com/v3/businesses/search ...
# Skipping...
# Skipping...
# Skipping...
# Skipping...
# Skipping...
# Skipping...
# Skipping...
# Skipping...
# Skipping...
# Skipping...
# Skipping...
# Querying https://api.yelp.com/v3/businesses/search ...
# Skipping...
# Skipping...
# Skipping...
# Skipping...
# Skipping...
# Skipping...
# Skipping...
# Skipping...
# Skipping...
# Skipping...
# Querying https://api.yelp.com/v3/businesses/search ...
# Skipping...
# Skipping...
# Skipping...
# Skipping...
# Skipping...
# Skipping...
# Skipping...
# Skipping...
# Skipping...
# Skipping...
# Skipping...
# Skipping...
# Skipping...
# Querying https://api.yelp.com/v3/businesses/search ...
# Skipping...
# Skipping...
# Skipping...
# Skipping...
# Skipping...
# Querying https://api.yelp.com/v3/businesses/search ...
# Skipping...
# Skipping...
# Skipping...
# Skipping...
# Skipping...
# Skipping...
# Skipping...
# Skipping...
# Skipping...
# Querying https://api.yelp.com/v3/businesses/search ...
# Skipping...
# Skipping...
# Skipping...
# Skipping...
# Skipping...
# Skipping...
# Skipping...
# Skipping...
# Querying https://api.yelp.com/v3/businesses/search ...
# Skipping...
# Skipping...
# Skipping...
# Skipping...
# Skipping...
# Skipping...
# Skipping...
# Skipping...
# Querying https://api.yelp.com/v3/businesses/search ...
# Skipping...
# Skipping...
# Skipping...
# Skipping...
# Skipping...
# Skipping...
# Skipping...
# Skipping...
# Skipping...
# Querying https://api.yelp.com/v3/businesses/search ...
# Skipping...
# Skipping...
# Skipping...
# Skipping...
# Skipping...
# Skipping...
# Querying https://api.yelp.com/v3/businesses/search ...
# Skipping...
# Skipping...
# Skipping...
# Skipping...
# Skipping...
# Skipping...
# Skipping...
# Querying https://api.yelp.com/v3/businesses/search ...
# Skipping...
# Skipping...
# Skipping...
# Querying https://api.yelp.com/v3/businesses/search ...
# Skipping...
# Skipping...
# Skipping...
# Querying https://api.yelp.com/v3/businesses/search ...
# Skipping...
# Skipping...
# Skipping...
# Skipping...
# Querying https://api.yelp.com/v3/businesses/search ...
# Skipping...
# Skipping...
# Skipping...
# Skipping...
# Skipping...
# Skipping...
# Querying https://api.yelp.com/v3/businesses/search ...
# Skipping...
# Skipping...
# Skipping...
# Querying https://api.yelp.com/v3/businesses/search ...
# Skipping...
# Skipping...
# Skipping...
# Skipping...
# Skipping...
# Skipping...
# Querying https://api.yelp.com/v3/businesses/search ...
# Skipping...
# Skipping...
# Skipping...
# Skipping...
# Skipping...
# Skipping...
# Skipping...
# Skipping...
# Querying https://api.yelp.com/v3/businesses/search ...
# Skipping...
# Skipping...
# Skipping...
# Skipping...
# Skipping...
# Skipping...
# Querying https://api.yelp.com/v3/businesses/search ...
# Skipping...
# Skipping...
# Skipping...
# Querying https://api.yelp.com/v3/businesses/search ...
# Skipping...
# Skipping...
# Querying https://api.yelp.com/v3/businesses/search ...
# Skipping...
# Skipping...
# Skipping...
# Skipping...
# Skipping...
# Skipping...
# Skipping...
# Skipping...
# Skipping...
# Querying https://api.yelp.com/v3/businesses/search ...
# Skipping...
# Skipping...
# Querying https://api.yelp.com/v3/businesses/search ...
# Skipping...
# Skipping...
# Skipping...
# Skipping...
# Skipping...
# Skipping...
# Querying https://api.yelp.com/v3/businesses/search ...
# Skipping...
# Skipping...
# Skipping...
# Skipping...
# Skipping...
# Skipping...
# Querying https://api.yelp.com/v3/businesses/search ...
# Skipping...
# Querying https://api.yelp.com/v3/businesses/search ...
# Skipping...
# Skipping...
# Skipping...
# Skipping...
# Skipping...
# Querying https://api.yelp.com/v3/businesses/search ...
# Skipping...
# Skipping...
# Skipping...
# Skipping...
# Querying https://api.yelp.com/v3/businesses/search ...
# Skipping...
# Skipping...
# Skipping...
# Skipping...
# Skipping...
# Querying https://api.yelp.com/v3/businesses/search ...
# Skipping...
# Skipping...
# Skipping...
# Skipping...
# Querying https://api.yelp.com/v3/businesses/search ...
# Skipping...
# Skipping...
# Querying https://api.yelp.com/v3/businesses/search ...
# Skipping...
# Querying https://api.yelp.com/v3/businesses/search ...
# Querying https://api.yelp.com/v3/businesses/search ...
# Skipping...
# Skipping...
# Skipping...
# Skipping...
# Skipping...
# Skipping...
# Querying https://api.yelp.com/v3/businesses/search ...
# Skipping...
# Skipping...
# Skipping...
# Skipping...
# Querying https://api.yelp.com/v3/businesses/search ...
# Skipping...
# Skipping...
# Skipping...
# Skipping...
# Skipping...
# Skipping...
# Querying https://api.yelp.com/v3/businesses/search ...
# Skipping...
# Skipping...
# Skipping...
# Skipping...
# Skipping...
# Skipping...
# Skipping...
# Skipping...
# Skipping...
# Skipping...
# Querying https://api.yelp.com/v3/businesses/search ...
# Skipping...
# Skipping...
# Skipping...
# Skipping...
# Skipping...
# Skipping...
# Skipping...
# Skipping...
# Skipping...
# Querying https://api.yelp.com/v3/businesses/search ...
# Skipping...
# Querying https://api.yelp.com/v3/businesses/search ...
# Skipping...
# Skipping...
# Skipping...
# Skipping...
# Skipping...
# Skipping...
# Skipping...
# Skipping...
# Skipping...
# Skipping...
# Skipping...
# Skipping...
# Skipping...
# Skipping...
# Querying https://api.yelp.com/v3/businesses/search ...
# Skipping...
# Skipping...
# Skipping...
# Skipping...
# Skipping...
# Skipping...
# Querying https://api.yelp.com/v3/businesses/search ...
# Skipping...
# Skipping...
# Skipping...
# Skipping...
# Skipping...
# Skipping...
# Skipping...
# Skipping...
# Skipping...
# Skipping...
# Skipping...
# Skipping...
# Skipping...
# Skipping...
# Querying https://api.yelp.com/v3/businesses/search ...
# Skipping...
# Skipping...
# Skipping...
# Skipping...
# Skipping...
# Skipping...
# Querying https://api.yelp.com/v3/businesses/search ...
# Querying https://api.yelp.com/v3/businesses/search ...
# Querying https://api.yelp.com/v3/businesses/search ...
# Querying https://api.yelp.com/v3/businesses/search ...
# Querying https://api.yelp.com/v3/businesses/search ...
# Querying https://api.yelp.com/v3/businesses/search ...
# Querying https://api.yelp.com/v3/businesses/search ...
# Querying https://api.yelp.com/v3/businesses/search ...
# Querying https://api.yelp.com/v3/businesses/search ...
# Querying https://api.yelp.com/v3/businesses/search ...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
restaurant_data
# Out:
# [{'id': 'Vp1kiliceNp6_K8tkRCTCg',
#   'name': 'La Cocina Restaurant',
#   'review_count': 495,
#   'category': 'Mexican',
#   'rating': 4.0,
#   'price': '$',
#   'city': 'Portland',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.550892,
#   'Lng': -122.667025},
#  {'id': 'UZUjgF7XW7WkvyUb8_qCiA',
#   'name': 'Matador NW Portland',
#   'review_count': 871,
#   'category': 'Mexican',
#   'rating': 3.5,
#   'price': '$$',
#   'city': 'Portland',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.5332,
#   'Lng': -122.69846},
#  {'id': 'B0fBpezDvj2Bp-8KOlMMRw',
#   'name': 'Nuestra Cocina',
#   'review_count': 614,
#   'category': 'Mexican',
#   'rating': 4.5,
#   'price': '$$',
#   'city': 'Portland',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.50503,
#   'Lng': -122.64379},
#  {'id': 'Ir1GUgWHVsXpJeRTfk0HTQ',
#   'name': "Carlita's - Portland",
#   'review_count': 223,
#   'category': 'Other',
#   'rating': 4.0,
#   'price': '$$',
#   'city': 'Portland',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.53172,
#   'Lng': -122.68295},
#  {'id': '4ZPcXpYcmsoiZQGn5M8JuQ',
#   'name': 'Por Qué No? Taqueria',
#   'review_count': 1312,
#   'category': 'Mexican',
#   'rating': 4.0,
#   'price': '$$',
#   'city': 'Portland',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.54824,
#   'Lng': -122.67524},
#  {'id': '3L-ezs0VANOtmdJDlbha1Q',
#   'name': 'Güero',
#   'review_count': 626,
#   'category': 'Mexican',
#   'rating': 4.5,
#   'price': '$$',
#   'city': 'Portland',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.5244618,
#   'Lng': -122.6370351},
#  {'id': 'eUbq0uNxRlXQ6sy7phM7yA',
#   'name': 'Lechon',
#   'review_count': 1736,
#   'category': 'Other',
#   'rating': 4.5,
#   'price': '$$$',
#   'city': 'Portland',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.52129,
#   'Lng': -122.67094},
#  {'id': 'WWlkufMDXMmgOjnD_s1Wfg',
#   'name': 'Matador East Portland',
#   'review_count': 567,
#   'category': 'Mexican',
#   'rating': 3.5,
#   'price': '$$',
#   'city': 'Portland',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.5226289,
#   'Lng': -122.64089},
#  {'id': 'ReDp_lzWLJHDOTzNEBkeqg',
#   'name': 'El Yike Oaxaqueno',
#   'review_count': 8,
#   'category': 'Mexican',
#   'rating': 5.0,
#   'price': '$$',
#   'city': 'Portland',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.57725687417561,
#   'Lng': -122.695073},
#  {'id': 'Wm3pOIWzjzttU7TgGGyM7Q',
#   'name': 'La Taq',
#   'review_count': 234,
#   'category': 'Mexican',
#   'rating': 4.0,
#   'price': '$$',
#   'city': 'Portland',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.56283,
#   'Lng': -122.64849414110448},
#  {'id': 'T1PWwJlkRKQfRfkSwaa2Mg',
#   'name': "Nico's Cantina",
#   'review_count': 21,
#   'category': 'Other',
#   'rating': 3.5,
#   'price': '$$',
#   'city': 'Portland',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.554019,
#   'Lng': -122.601719},
#  {'id': 'WytdX0Qxe_w0IeeHx7A69A',
#   'name': 'Casa Colima',
#   'review_count': 310,
#   'category': 'Mexican',
#   'rating': 4.0,
#   'price': '$$',
#   'city': 'Portland',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.4787,
#   'Lng': -122.69502},
#  {'id': 'vUteYFB9WGCei_onyTpm4g',
#   'name': 'Mi Cava & Cocina',
#   'review_count': 104,
#   'category': 'Mexican',
#   'rating': 4.0,
#   'price': '$$',
#   'city': 'Portland',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.51723,
#   'Lng': -122.56305},
#  {'id': 'kqZa61d6WUJ717Enm5t9ow',
#   'name': 'Si Senor',
#   'review_count': 556,
#   'category': 'Mexican',
#   'rating': 4.0,
#   'price': '$$',
#   'city': 'Beaverton',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.46082,
#   'Lng': -122.793185},
#  {'id': '-3hnEon-pSQRGPDr80s3Gw',
#   'name': 'El Burrito Azteca',
#   'review_count': 302,
#   'category': 'Mexican',
#   'rating': 4.0,
#   'price': '$',
#   'city': 'Portland',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.56965,
#   'Lng': -122.6871},
#  {'id': 'S9zEhTEukbJog-T6g4XnCQ',
#   'name': 'El Sombrero Mexican Cocina',
#   'review_count': 203,
#   'category': 'Mexican',
#   'rating': 4.0,
#   'price': '$$',
#   'city': 'Portland',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.5585472285748,
#   'Lng': -122.551365047693},
#  {'id': 'jKJ7zgb8epZmSFb3PSQvhQ',
#   'name': 'El Indio',
#   'review_count': 267,
#   'category': 'Mexican',
#   'rating': 3.5,
#   'price': '$$',
#   'city': 'Portland',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.5334551632404,
#   'Lng': -122.548278495669},
#  {'id': 'C1MgjUIvsFjhQCKAlTH6jw',
#   'name': 'de Fuego',
#   'review_count': 373,
#   'category': 'Other',
#   'rating': 4.5,
#   'price': '$$',
#   'city': 'Clackamas',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.430992,
#   'Lng': -122.567432},
#  {'id': 'ufdfOHSK95tPN3FKvqt9jw',
#   'name': 'Mi Burrito',
#   'review_count': 215,
#   'category': 'Mexican',
#   'rating': 4.5,
#   'price': '$',
#   'city': 'Portland',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.57747,
#   'Lng': -122.67531},
#  {'id': 'SCO7tq7IZYbWHs1rqoHwZg',
#   'name': "Pepino's Mexican Grill",
#   'review_count': 412,
#   'category': 'Mexican',
#   'rating': 4.0,
#   'price': '$',
#   'city': 'Portland',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.52951,
#   'Lng': -122.69829},
#  {'id': '0Ro0-D1SALH5507zeKWV6w',
#   'name': 'Los Gorditos',
#   'review_count': 431,
#   'category': 'Mexican',
#   'rating': 4.0,
#   'price': '$',
#   'city': 'Portland',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.52419,
#   'Lng': -122.68084},
#  {'id': '3vWeEHMTXnndkz_3SIkvdQ',
#   'name': 'Mezcaluna',
#   'review_count': 140,
#   'category': 'Mexican',
#   'rating': 4.0,
#   'price': '$$',
#   'city': 'Happy Valley',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.43446610259169,
#   'Lng': -122.57245468859166},
#  {'id': 'LF0EuyDA4-rhb6s36q0wsQ',
#   'name': 'Andina',
#   'review_count': 3198,
#   'category': 'Other',
#   'rating': 4.5,
#   'price': '$$$',
#   'city': 'Portland',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.52633,
#   'Lng': -122.68459},
#  {'id': '3OhrI5CKbpgyy613lkneqA',
#   'name': 'Taqueria Nueve',
#   'review_count': 215,
#   'category': 'Mexican',
#   'rating': 4.0,
#   'price': '$$',
#   'city': 'Portland',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.5187560624832,
#   'Lng': -122.658058595148},
#  {'id': '0Ix62hICO6ypSXfhCvgE6Q',
#   'name': 'Por Qué No? Taqueria',
#   'review_count': 1340,
#   'category': 'Mexican',
#   'rating': 4.0,
#   'price': '$$',
#   'city': 'Portland',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.51226,
#   'Lng': -122.61434},
#  {'id': '1by7UBDdiBJ9_ZTR9r1uSA',
#   'name': 'Can Font',
#   'review_count': 244,
#   'category': 'Other',
#   'rating': 4.0,
#   'price': '$$',
#   'city': 'Portland',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.531594403375,
#   'Lng': -122.681575219574},
#  {'id': 'r_sOAVfNPaXrpjznZpuxeg',
#   'name': "Papi Chulo's",
#   'review_count': 320,
#   'category': 'Other',
#   'rating': 4.0,
#   'price': '$$',
#   'city': 'Portland',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.52747,
#   'Lng': -122.68448},
#  {'id': 'T1Gi5BN7eH99tu2x7q8RFA',
#   'name': 'Tope',
#   'review_count': 220,
#   'category': 'Mexican',
#   'rating': 4.0,
#   'price': '$$',
#   'city': 'Portland',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.523411924123565,
#   'Lng': -122.67474194299874},
#  {'id': '9LdZRadOxNbKs-5-DVEUXA',
#   'name': 'Ole Ole',
#   'review_count': 341,
#   'category': 'Mexican',
#   'rating': 4.0,
#   'price': '$',
#   'city': 'Portland',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.5231,
#   'Lng': -122.64377},
#  {'id': 'VDZYhy4uGbPvr0Mnfdka8Q',
#   'name': 'Mis Tacones',
#   'review_count': 62,
#   'category': 'Mexican',
#   'rating': 4.5,
#   'price': '$$',
#   'city': 'Portland',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.5626,
#   'Lng': -122.64799},
#  {'id': 'UH0KxI2ySS5iRHt1kEz-KQ',
#   'name': 'La Bonita',
#   'review_count': 433,
#   'category': 'Mexican',
#   'rating': 4.0,
#   'price': '$$',
#   'city': 'Portland',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.55919,
#   'Lng': -122.63606},
#  {'id': 'n16Hf7v3TpWKwjpKoV_01A',
#   'name': 'Bullard Tavern',
#   'review_count': 228,
#   'category': 'Other',
#   'rating': 4.0,
#   'price': '$$',
#   'city': 'Portland',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.520579918916,
#   'Lng': -122.680489942431},
#  {'id': 'IPZF4iK6ozgoAPlutAGcZQ',
#   'name': 'Casa Colima Mexican Restaurant & Cantina',
#   'review_count': 331,
#   'category': 'Mexican',
#   'rating': 4.5,
#   'price': '$$',
#   'city': 'Vancouver',
#   'state': 'WA',
#   'country': 'US',
#   'Lat': 45.66994741013798,
#   'Lng': -122.50749311898535},
#  {'id': 'xcLuF0F-zoQwWDKpQv8vyw',
#   'name': 'Mazatlan Mexican Restaurant',
#   'review_count': 156,
#   'category': 'Mexican',
#   'rating': 3.5,
#   'price': '$$',
#   'city': 'Portland',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.52286,
#   'Lng': -122.69361},
#  {'id': 'gpjXZmX9SYXWsVSN3TeKQw',
#   'name': 'Que Pasa Cantina',
#   'review_count': 362,
#   'category': 'Mexican',
#   'rating': 4.0,
#   'price': '$$',
#   'city': 'Portland',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.512706,
#   'Lng': -122.653457},
#  {'id': 'gXPeMjI_D92gG53mZZKmAA',
#   'name': 'Pambiche',
#   'review_count': 1609,
#   'category': 'Other',
#   'rating': 4.0,
#   'price': '$$',
#   'city': 'Portland',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.5266114238082,
#   'Lng': -122.636924008598},
#  {'id': 'bx6irVQ_0gY48Q2I5N7GmQ',
#   'name': 'Margarita Factory - Happy Valley',
#   'review_count': 226,
#   'category': 'Mexican',
#   'rating': 4.0,
#   'price': '$$',
#   'city': 'Happy Valley',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.44156683309567,
#   'Lng': -122.57983399006355},
#  {'id': '8Um9SNtNanyrHMxcokYttw',
#   'name': 'Saraveza',
#   'review_count': 300,
#   'category': 'Other',
#   'rating': 4.0,
#   'price': '$$',
#   'city': 'Portland',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.562585452425,
#   'Lng': -122.67718105388},
#  {'id': 'VEBfMPm0t1nimHOAXuMvrg',
#   'name': 'Verde Cocina en la Perla',
#   'review_count': 80,
#   'category': 'Mexican',
#   'rating': 4.0,
#   'price': '$$',
#   'city': 'Portland',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.527314,
#   'Lng': -122.683124},
#  {'id': 'ELkpJ8dACMnazfCuB3-BwQ',
#   'name': "Salsas Locas - Tortilleria Y Tienda DeLeon's",
#   'review_count': 202,
#   'category': 'Mexican',
#   'rating': 4.5,
#   'price': '$$',
#   'city': 'Portland',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.49004,
#   'Lng': -122.63732},
#  {'id': 'Pat5JokQ25YKtYfqYu9RlQ',
#   'name': 'Teote House Cafe',
#   'review_count': 873,
#   'category': 'Other',
#   'rating': 4.0,
#   'price': '$$',
#   'city': 'Portland',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.511369,
#   'Lng': -122.65371},
#  {'id': '62oY0A491inWXqi4LhgXMQ',
#   'name': 'Pinches Burros',
#   'review_count': 67,
#   'category': 'Mexican',
#   'rating': 4.5,
#   'price': '$',
#   'city': 'Portland',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.5557669837836,
#   'Lng': -122.602989524603},
#  {'id': 'oloBhDAbMhmqA8tlAChj4g',
#   'name': 'Nostrana',
#   'review_count': 1104,
#   'category': 'Italian',
#   'rating': 4.0,
#   'price': '$$$',
#   'city': 'Portland',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.51755,
#   'Lng': -122.6511},
#  {'id': 'u3tq9fqUpLT8xd8E9Rmcug',
#   'name': 'Ixtapa Family Mexican Restaurant',
#   'review_count': 131,
#   'category': 'Other',
#   'rating': 4.5,
#   'price': '$$',
#   'city': 'Portland',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.4919528125851,
#   'Lng': -122.487011812627},
#  {'id': 'in5nur8WHXW8Z6G2-RFllg',
#   'name': 'Chepes',
#   'review_count': 199,
#   'category': 'Mexican',
#   'rating': 4.5,
#   'price': '$',
#   'city': 'Portland',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.5193974313462,
#   'Lng': -122.482519948576},
#  {'id': 'itDQQBztG5kem20X3G51FQ',
#   'name': 'Teote Mezcalería',
#   'review_count': 96,
#   'category': 'Other',
#   'rating': 3.5,
#   'price': '$$$',
#   'city': 'Portland',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.55882,
#   'Lng': -122.63762},
#  {'id': '4YrYLgICcDzoTtmdg-YjYg',
#   'name': 'El Burrito Azteca',
#   'review_count': 267,
#   'category': 'Mexican',
#   'rating': 4.5,
#   'price': '$',
#   'city': 'Portland',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.54631,
#   'Lng': -122.59359},
#  {'id': 'j-uWRhJ9fpojdrBA9B_Bwg',
#   'name': 'Cabezon',
#   'review_count': 524,
#   'category': 'Other',
#   'rating': 4.0,
#   'price': '$$$',
#   'city': 'Portland',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.539867401123,
#   'Lng': -122.609588623047},
#  {'id': 'Auo7jjEmyT6mh3jlTeLtPA',
#   'name': 'The Antojitos House',
#   'review_count': 116,
#   'category': 'Other',
#   'rating': 5.0,
#   'price': '$$',
#   'city': 'Hillsboro',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.49974935730394,
#   'Lng': -122.90174119390743},
#  {'id': '9nxzFP7lN9FzHtIuW4Kybg',
#   'name': 'La Villa Grill & Bar',
#   'review_count': 49,
#   'category': 'Mexican',
#   'rating': 4.0,
#   'price': '$$',
#   'city': 'Portland',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.519211842376045,
#   'Lng': -122.4709134},
#  {'id': 'swtEBpuuy0TRdYM1NnZd1A',
#   'name': 'La Bonita',
#   'review_count': 112,
#   'category': 'Mexican',
#   'rating': 4.0,
#   'price': '$',
#   'city': 'Portland',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.56261,
#   'Lng': -122.69487},
#  {'id': 'rusBG96KJdOFYM1IJvFiGg',
#   'name': "Aztec Willie's Taqueria",
#   'review_count': 296,
#   'category': 'Mexican',
#   'rating': 3.0,
#   'price': '$$',
#   'city': 'Portland',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.5351418,
#   'Lng': -122.6502247},
#  {'id': '8UhWnbf1bDShI8WIQRmECQ',
#   'name': 'Wilder',
#   'review_count': 193,
#   'category': 'Other',
#   'rating': 4.5,
#   'price': '$$',
#   'city': 'Portland',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.56293,
#   'Lng': -122.63519},
#  {'id': 'NFb4zqgY-P2A_ISUnJQsnw',
#   'name': 'La Parrilla Kitchen',
#   'review_count': 243,
#   'category': 'Mexican',
#   'rating': 4.5,
#   'price': '$',
#   'city': 'Beaverton',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.47138945472726,
#   'Lng': -122.77381502171657},
#  {'id': 'BqGbGoHZW6PC6wYifuHfzg',
#   'name': 'Holy Taco',
#   'review_count': 333,
#   'category': 'Mexican',
#   'rating': 3.5,
#   'price': '$$',
#   'city': 'Lake Oswego',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.41866,
#   'Lng': -122.66415},
#  {'id': 'M_KWezij-FDKwiNSEamQmg',
#   'name': 'Tienda Santa Cruz',
#   'review_count': 534,
#   'category': 'Mexican',
#   'rating': 4.5,
#   'price': '$',
#   'city': 'Portland',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.59024,
#   'Lng': -122.75531},
#  {'id': 'OThSRLbbRDTAKcjK2WLYzw',
#   'name': 'Chez Jose Mexican Cafe',
#   'review_count': 208,
#   'category': 'Mexican',
#   'rating': 3.5,
#   'price': '$$',
#   'city': 'Portland',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.46341,
#   'Lng': -122.68401},
#  {'id': 'nAgWcMOCl35QO6XSZSR_QQ',
#   'name': 'La Isla Bonita',
#   'review_count': 91,
#   'category': 'Mexican',
#   'rating': 3.5,
#   'price': '$$',
#   'city': 'Portland',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.5247,
#   'Lng': -122.53702},
#  {'id': '988jPD-fyQKU-FxNRKsfrw',
#   'name': 'The Fireside',
#   'review_count': 449,
#   'category': 'Other',
#   'rating': 4.0,
#   'price': '$$',
#   'city': 'Portland',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.52856877661314,
#   'Lng': -122.69876217055287},
#  {'id': 'HaH-2or9dp2EeveWzmHd_w',
#   'name': 'La Sirenita',
#   'review_count': 304,
#   'category': 'Mexican',
#   'rating': 4.0,
#   'price': '$',
#   'city': 'Portland',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.55923,
#   'Lng': -122.63643},
#  {'id': '3203k1hyaxa3PxkKL0R9Ow',
#   'name': 'Arden ',
#   'review_count': 178,
#   'category': 'Other',
#   'rating': 4.5,
#   'price': '$$$',
#   'city': 'Portland',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.5261799,
#   'Lng': -122.68173},
#  {'id': 'FvznHQIX9APsAvxPbS5rYQ',
#   'name': 'Tropicale',
#   'review_count': 132,
#   'category': 'Other',
#   'rating': 4.0,
#   'price': '$$',
#   'city': 'Portland',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.526651,
#   'Lng': -122.6416165},
#  {'id': 'Kx1KWIVkpp4JvDDz3YTnTg',
#   'name': 'Tamale Boy',
#   'review_count': 156,
#   'category': 'Mexican',
#   'rating': 4.5,
#   'price': '$$',
#   'city': 'Portland',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.5409896,
#   'Lng': -122.6732311},
#  {'id': 'milE0SqkjLvuQl0cOw2oag',
#   'name': 'Tacovore',
#   'review_count': 150,
#   'category': 'Other',
#   'rating': 4.0,
#   'price': '$$',
#   'city': 'Portland',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.5485,
#   'Lng': -122.62454},
#  {'id': 'hqLo_9L-FUJZa4z6uqdP7g',
#   'name': "Rocio's",
#   'review_count': 326,
#   'category': 'Mexican',
#   'rating': 4.0,
#   'price': '$$',
#   'city': 'Portland',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.493189,
#   'Lng': -122.6363311},
#  {'id': 'Tjkzssv2oQXTBUl2P-pPFA',
#   'name': 'Pig Patas Tacos',
#   'review_count': 203,
#   'category': 'Other',
#   'rating': 4.5,
#   'price': '$$',
#   'city': 'Portland',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.56292,
#   'Lng': -122.660451},
#  {'id': 'd69y3CN9_SQKrEnXXqQr8g',
#   'name': 'King Burrito Mexican Food',
#   'review_count': 596,
#   'category': 'Mexican',
#   'rating': 4.5,
#   'price': '$',
#   'city': 'Portland',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.5769701,
#   'Lng': -122.6971121},
#  {'id': 'orww93GoyE5Z2a06L7KxoQ',
#   'name': 'Little Conejo',
#   'review_count': 568,
#   'category': 'Mexican',
#   'rating': 4.0,
#   'price': '$$',
#   'city': 'Vancouver',
#   'state': 'WA',
#   'country': 'US',
#   'Lat': 45.62580646015779,
#   'Lng': -122.67249697218331},
#  {'id': 'VPRJKxUGHn4fQO4qnClyAQ',
#   'name': 'Love Belizean',
#   'review_count': 157,
#   'category': 'Other',
#   'rating': 5.0,
#   'price': '$$',
#   'city': 'Portland',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.5138504248003,
#   'Lng': -122.682890986639},
#  {'id': 'ND581JIp6UnwD9hKpD_MHw',
#   'name': 'Verde Cocina - Hillsdale',
#   'review_count': 411,
#   'category': 'Mexican',
#   'rating': 4.0,
#   'price': '$$',
#   'city': 'Portland',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.4776746034622,
#   'Lng': -122.699155434966},
#  {'id': '83jn4RTSxY--ZP_nbYm_XA',
#   'name': 'Mestizo',
#   'review_count': 152,
#   'category': 'Other',
#   'rating': 4.5,
#   'price': '$$',
#   'city': 'Portland',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.5046751,
#   'Lng': -122.635322},
#  {'id': 'U-cbcBJR-j7Z0m_DT8zEGw',
#   'name': 'El Tapatio Restaurant',
#   'review_count': 114,
#   'category': 'Mexican',
#   'rating': 3.5,
#   'price': '$$',
#   'city': 'Portland',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.5038414001465,
#   'Lng': -122.579055786133},
#  {'id': 'otIr_HdP72Mceob6_2NFmA',
#   'name': 'La Tia Juana Taqueria',
#   'review_count': 102,
#   'category': 'Mexican',
#   'rating': 4.5,
#   'price': '$$',
#   'city': 'Portland',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.5209,
#   'Lng': -122.47292},
#  {'id': '03kruYCXHxj097eicu-3Cw',
#   'name': 'Nacheaux',
#   'review_count': 105,
#   'category': 'Mexican',
#   'rating': 5.0,
#   'price': '$$',
#   'city': 'Portland',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.51751080958338,
#   'Lng': -122.6609934},
#  {'id': 's0UOpHA_EeLUJDsziUiV_Q',
#   'name': "Who Song & Larry's",
#   'review_count': 615,
#   'category': 'Mexican',
#   'rating': 3.5,
#   'price': '$$',
#   'city': 'Vancouver',
#   'state': 'WA',
#   'country': 'US',
#   'Lat': 45.6208360418657,
#   'Lng': -122.671187354344},
#  {'id': 'ncRoLv6zWxQaMjLj1ZC_uA',
#   'name': 'Expatriate',
#   'review_count': 288,
#   'category': 'Other',
#   'rating': 4.0,
#   'price': '$$',
#   'city': 'Portland',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.5623529,
#   'Lng': -122.6348562},
#  {'id': 'GSW508Gb5ugE6ZHCqeuwUg',
#   'name': 'Don Kamaron',
#   'review_count': 134,
#   'category': 'Mexican',
#   'rating': 4.0,
#   'price': '$$',
#   'city': 'Portland',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.5188614,
#   'Lng': -122.4952468},
#  {'id': 'OT7iklmaiTrqa_nHLkuLFg',
#   'name': 'Bar Casa Vale',
#   'review_count': 209,
#   'category': 'Other',
#   'rating': 4.0,
#   'price': '$$$',
#   'city': 'Portland',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.52114,
#   'Lng': -122.65697},
#  {'id': 'fX3MMoxm5KgYWMjcQbXYlQ',
#   'name': 'Cadillac Cafe',
#   'review_count': 656,
#   'category': 'Other',
#   'rating': 4.0,
#   'price': '$$',
#   'city': 'Portland',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.535192,
#   'Lng': -122.647486},
#  {'id': 'IGeY8YKOT7bmqwCXaBCwQA',
#   'name': 'Saint Burrito',
#   'review_count': 88,
#   'category': 'Mexican',
#   'rating': 4.5,
#   'price': '$',
#   'city': 'Portland',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.5218797,
#   'Lng': -122.6374149},
#  {'id': 'BirfrRk74soiX5HYn-sZFA',
#   'name': 'Mariscos el Malecon',
#   'review_count': 57,
#   'category': 'Mexican',
#   'rating': 4.0,
#   'price': '$$',
#   'city': 'Portland',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.56711,
#   'Lng': -122.60313},
#  {'id': 'Hxh5rOotLNQUzEF5ekTYjg',
#   'name': 'J&R Mexican Food',
#   'review_count': 57,
#   'category': 'Mexican',
#   'rating': 4.5,
#   'price': '$$',
#   'city': 'Oak Grove',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.42331,
#   'Lng': -122.63412},
#  {'id': 'Irp5sgl7XASH5ZTw2D47qw',
#   'name': 'Navarre',
#   'review_count': 441,
#   'category': 'Italian',
#   'rating': 4.0,
#   'price': '$$',
#   'city': 'Portland',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.5230522155762,
#   'Lng': -122.637211158872},
#  {'id': '7P_cB08eWzCzBRzg0rkMCw',
#   'name': 'Sabor Salvadoreño',
#   'review_count': 299,
#   'category': 'Other',
#   'rating': 4.5,
#   'price': '$',
#   'city': 'Beaverton',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.494966,
#   'Lng': -122.866633},
#  {'id': 'QSL69ZUkq4iEjJmmRqmA8w',
#   'name': "Amelia's Restaurant",
#   'review_count': 566,
#   'category': 'Mexican',
#   'rating': 4.0,
#   'price': '$$',
#   'city': 'Hillsboro',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.52274,
#   'Lng': -122.9845},
#  {'id': '90nu9SmFfQaXsoWoZGB0mQ',
#   'name': 'Murata Restaurant',
#   'review_count': 374,
#   'category': 'Other',
#   'rating': 4.5,
#   'price': '$$',
#   'city': 'Portland',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.511592,
#   'Lng': -122.678604},
#  {'id': 'DlGKrxoFV8iQJr1k5x04Nw',
#   'name': 'Panaderia Mexicana Cinco De Mayo',
#   'review_count': 92,
#   'category': 'Mexican',
#   'rating': 4.5,
#   'price': '$',
#   'city': 'Portland',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.46199,
#   'Lng': -122.6296},
#  {'id': '78Gdq4rhx7LHRFO6f-WbsQ',
#   'name': 'El Jefe Taqueria & Mexican Grill',
#   'review_count': 137,
#   'category': 'Other',
#   'rating': 4.5,
#   'price': '$',
#   'city': 'Beaverton',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.476773,
#   'Lng': -122.800621},
#  {'id': 'AbSIqDPWxkaoPDrVsFgoEw',
#   'name': 'CUBO de cuba',
#   'review_count': 506,
#   'category': 'Other',
#   'rating': 4.0,
#   'price': '$$',
#   'city': 'Portland',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.5119602847625,
#   'Lng': -122.633606393486},
#  {'id': 'TvZ-8ZEcsv93UvMQXnvOug',
#   'name': 'Papa Haydn Northwest',
#   'review_count': 1296,
#   'category': 'Other',
#   'rating': 4.0,
#   'price': '$$',
#   'city': 'Portland',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.52787,
#   'Lng': -122.69876},
#  {'id': 'P8Kp10s_s8iHH5ZPQrtDVg',
#   'name': 'Pepper Box Cafe',
#   'review_count': 314,
#   'category': 'Mexican',
#   'rating': 4.5,
#   'price': '$',
#   'city': 'Portland',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.5170111,
#   'Lng': -122.655953},
#  {'id': 'kiAZhedjIcvx6rWQn6V42g',
#   'name': 'Blossoming Lotus',
#   'review_count': 1299,
#   'category': 'Other',
#   'rating': 4.5,
#   'price': '$$',
#   'city': 'Portland',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.535498,
#   'Lng': -122.650834},
#  {'id': 'E9fvKLJahuwg95kQk7xS9Q',
#   'name': 'Nayar Taqueria',
#   'review_count': 317,
#   'category': 'Mexican',
#   'rating': 4.5,
#   'price': '$$',
#   'city': 'Portland',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.4923684149981,
#   'Lng': -122.602166086435},
#  {'id': '_zJmurMkotgE_ALtp4D5Kg',
#   'name': 'Mixteca Mexican Restaurant',
#   'review_count': 114,
#   'category': 'Mexican',
#   'rating': 4.5,
#   'price': '$',
#   'city': 'Portland',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.5064174,
#   'Lng': -122.5783464},
#  {'id': '6Amy_pW-N7wF3yYy08R7mg',
#   'name': 'Tamale Boy',
#   'review_count': 469,
#   'category': 'Mexican',
#   'rating': 4.5,
#   'price': '$',
#   'city': 'Portland',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.57164,
#   'Lng': -122.647},
#  {'id': 'bhfzhAnhEbE5ro6aNre8xw',
#   'name': 'Pollo Norte',
#   'review_count': 191,
#   'category': 'Mexican',
#   'rating': 4.0,
#   'price': '$$',
#   'city': 'Portland',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.52672,
#   'Lng': -122.63511},
#  {'id': 'E6aYeFovWUzogH0ygo31jg',
#   'name': 'Ox',
#   'review_count': 1194,
#   'category': 'Other',
#   'rating': 4.5,
#   'price': '$$$',
#   'city': 'Portland',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.53935,
#   'Lng': -122.66213},
#  {'id': 'L9Sonuly21RpR677bL-k4Q',
#   'name': 'Ixtapa Mexican Restaurant',
#   'review_count': 90,
#   'category': 'Mexican',
#   'rating': 3.5,
#   'price': '$$',
#   'city': 'Scappoose',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.74092,
#   'Lng': -122.87932},
#  {'id': 'EhnjTa039BgJvwDbxjRRBg',
#   'name': 'Lindo Mexico Restaurant and Cantina',
#   'review_count': 167,
#   'category': 'Mexican',
#   'rating': 3.5,
#   'price': '$$',
#   'city': 'Vancouver',
#   'state': 'WA',
#   'country': 'US',
#   'Lat': 45.618763,
#   'Lng': -122.546911},
#  {'id': 'GHuliK23HiSurTLi2GnJ4g',
#   'name': 'Casa del Pollo',
#   'review_count': 339,
#   'category': 'Other',
#   'rating': 4.5,
#   'price': '$',
#   'city': 'Lake Oswego',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.41313494784702,
#   'Lng': -122.71684235282945},
#  {'id': '82E6Mzc7D98FmlaqCfq5Yw',
#   'name': 'Antojitos Mexicanos',
#   'review_count': 160,
#   'category': 'Mexican',
#   'rating': 4.5,
#   'price': '$',
#   'city': 'Portland',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.5577122751383,
#   'Lng': -122.544000093214},
#  {'id': 'xLK-nQFpe0uxdGMlmZZqJg',
#   'name': 'Santa Fe Taqueria',
#   'review_count': 368,
#   'category': 'Mexican',
#   'rating': 3.0,
#   'price': '$$',
#   'city': 'Portland',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.528919,
#   'Lng': -122.698806},
#  {'id': 'x2v-vBC17E5NOf3CqBEG1w',
#   'name': 'Maria Bonita Mexican Grill',
#   'review_count': 170,
#   'category': 'Mexican',
#   'rating': 4.0,
#   'price': '$$',
#   'city': 'Beaverton',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.49234,
#   'Lng': -122.80698},
#  {'id': 'OuXvzo3mGDVVj6y4WpsfSg',
#   'name': 'Poblano Pepper',
#   'review_count': 13,
#   'category': 'Mexican',
#   'rating': 5.0,
#   'price': '$$',
#   'city': 'Portland',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.51008,
#   'Lng': -122.68367},
#  {'id': 'HnvWkLB6K_zzTrbV_JjxHA',
#   'name': 'San Francisco Carniceria',
#   'review_count': 166,
#   'category': 'Mexican',
#   'rating': 4.0,
#   'price': '$',
#   'city': 'Wilsonville',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.30359,
#   'Lng': -122.76692},
#  {'id': 'SoOA3DnIxTS5ZgwnyASF3Q',
#   'name': "Salvador Molly's",
#   'review_count': 684,
#   'category': 'Other',
#   'rating': 3.5,
#   'price': '$$',
#   'city': 'Portland',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.479601,
#   'Lng': -122.694035},
#  {'id': 'wsw77Ib7qrTNpVTAHAiUbg',
#   'name': 'Burrito Bar',
#   'review_count': 235,
#   'category': 'Mexican',
#   'rating': 4.0,
#   'price': '$',
#   'city': 'Portland',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.5273579,
#   'Lng': -122.68050480768564},
#  {'id': 'K2k3pcyxJg2iYLZAaugtAA',
#   'name': 'Taqueria Portland',
#   'review_count': 208,
#   'category': 'Mexican',
#   'rating': 4.0,
#   'price': '$',
#   'city': 'Portland',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.5168299,
#   'Lng': -122.6576199},
#  {'id': '_WbZb29KIzsUZ0bzU19JoA',
#   'name': 'El Tapatio Restaurant',
#   'review_count': 108,
#   'category': 'Mexican',
#   'rating': 3.5,
#   'price': '$$',
#   'city': 'Portland',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.413319,
#   'Lng': -122.628874},
#  {'id': 'KAePC0kVwkL-24i27eA4_g',
#   'name': 'Sahuayo Taqueria',
#   'review_count': 64,
#   'category': 'Other',
#   'rating': 4.5,
#   'price': '$',
#   'city': 'Portland',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.526180416441164,
#   'Lng': -122.61654350000174},
#  {'id': '9hM3xRci3qGp6O7dxdq9Lw',
#   'name': 'Gonzalez Taqueria',
#   'review_count': 58,
#   'category': 'Mexican',
#   'rating': 4.5,
#   'price': '$',
#   'city': 'Portland',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.5625251,
#   'Lng': -122.6830881},
#  {'id': 'qm4zJqfqIVWEZtFl-8ouDA',
#   'name': "Amelia's Rustic Mexican Restaurant",
#   'review_count': 248,
#   'category': 'Mexican',
#   'rating': 4.0,
#   'price': '$$',
#   'city': 'Hillsboro',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.53958,
#   'Lng': -122.96117},
#  {'id': 'quUZWkl9zTCryliPr665ng',
#   'name': "Rosie's Kitchen",
#   'review_count': 230,
#   'category': 'Mexican',
#   'rating': 4.5,
#   'price': '$',
#   'city': 'Tualatin',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.3829540493596,
#   'Lng': -122.76032757014},
#  {'id': 'GOr1TsCtpk9A2uxTohSgRw',
#   'name': 'Nuestra Mesa',
#   'review_count': 384,
#   'category': 'Mexican',
#   'rating': 3.5,
#   'price': '$$',
#   'city': 'Camas',
#   'state': 'WA',
#   'country': 'US',
#   'Lat': 45.5851149,
#   'Lng': -122.4052149},
#  {'id': '532LOoLk3gnnFpTRTfX12Q',
#   'name': 'RJ Skillets',
#   'review_count': 102,
#   'category': 'Mexican',
#   'rating': 5.0,
#   'price': '$$',
#   'city': 'Portland',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.5592,
#   'Lng': -122.6392},
#  {'id': 'TindL0Ls66sxy-7N98S77w',
#   'name': 'Jefe Mex',
#   'review_count': 421,
#   'category': 'Mexican',
#   'rating': 3.5,
#   'price': '$$',
#   'city': 'Lake Oswego',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.4072883985136,
#   'Lng': -122.723762793115},
#  {'id': 'JVVQgiAdo4ZNxoRO2kN7EQ',
#   'name': 'La Hacienda Real',
#   'review_count': 307,
#   'category': 'Mexican',
#   'rating': 3.5,
#   'price': '$$',
#   'city': 'Beaverton',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.48922,
#   'Lng': -122.80045},
#  {'id': '_U_lsW-xvGd3ixKiQmor7A',
#   'name': 'Portland Mercado',
#   'review_count': 167,
#   'category': 'Mexican',
#   'rating': 4.5,
#   'price': '$$',
#   'city': 'Portland',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.48597,
#   'Lng': -122.58863},
#  {'id': 'qpUfRUfVud2EAt3ejz1Olw',
#   'name': 'La Industria',
#   'review_count': 94,
#   'category': 'Other',
#   'rating': 3.5,
#   'price': '$$',
#   'city': 'Tualatin',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.372881,
#   'Lng': -122.793193},
#  {'id': 'qaiL-S2njRJGWoe123BmbQ',
#   'name': 'Rauls Family Mexican Restaurant',
#   'review_count': 374,
#   'category': 'Mexican',
#   'rating': 4.0,
#   'price': '$$',
#   'city': 'Portland',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.48518,
#   'Lng': -122.7545951},
#  {'id': 'GgDKxGZBmzdyWmExESK14g',
#   'name': 'The Observatory',
#   'review_count': 2205,
#   'category': 'Other',
#   'rating': 4.5,
#   'price': '$$',
#   'city': 'Portland',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.519263,
#   'Lng': -122.580217},
#  {'id': 'l4kxnh1SBhpSPcxD37lL-w',
#   'name': "Allan's Authentic Mexican Restaurant",
#   'review_count': 304,
#   'category': 'Mexican',
#   'rating': 3.5,
#   'price': '$$',
#   'city': 'Portland',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.55845,
#   'Lng': -122.86522},
#  {'id': 'MmXz2xAQO3ZIRLyWh8zCPw',
#   'name': 'Maria Latina',
#   'review_count': 87,
#   'category': 'Other',
#   'rating': 4.5,
#   'price': '$',
#   'city': 'Tigard',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.427438,
#   'Lng': -122.750458},
#  {'id': 'S26gxay5At1uey7JuYEtfQ',
#   'name': 'Trattoria Gallo Nero',
#   'review_count': 306,
#   'category': 'Italian',
#   'rating': 4.0,
#   'price': '$$',
#   'city': 'Portland',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.5255,
#   'Lng': -122.68065},
#  {'id': 'VWbDjYlf0X49P6TYFROeHw',
#   'name': 'Mi Casa Pupuseria y Mexican Restaurant',
#   'review_count': 68,
#   'category': 'Mexican',
#   'rating': 5.0,
#   'price': '$$',
#   'city': 'Vancouver',
#   'state': 'WA',
#   'country': 'US',
#   'Lat': 45.637684,
#   'Lng': -122.635253},
#  {'id': 'v0DgJIt8vk491BCuHDfcMA',
#   'name': 'Casa Lola Kitchen de Mexico',
#   'review_count': 419,
#   'category': 'Other',
#   'rating': 4.0,
#   'price': '$$',
#   'city': 'Beaverton',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.42727061809182,
#   'Lng': -122.84502660552229},
#  {'id': 'nqp4E-tYuEJ5krF-dBF6TQ',
#   'name': 'El Inka',
#   'review_count': 171,
#   'category': 'Other',
#   'rating': 4.0,
#   'price': '$$',
#   'city': 'Portland',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.5044354,
#   'Lng': -122.5743978},
#  {'id': '7EbGTD7ZF30vEFBiHyN_0A',
#   'name': "McCormick & Schmick's Harborside at the Marina",
#   'review_count': 684,
#   'category': 'Other',
#   'rating': 3.0,
#   'price': '$$$',
#   'city': 'Portland',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.50941180247166,
#   'Lng': -122.67340788282449},
#  {'id': 'DBqFcdH_3nQ_C7eSjDGMAA',
#   'name': 'Los Alambres',
#   'review_count': 93,
#   'category': 'Mexican',
#   'rating': 4.5,
#   'price': '$',
#   'city': 'Vancouver',
#   'state': 'WA',
#   'country': 'US',
#   'Lat': 45.62735110422176,
#   'Lng': -122.60584824057048},
#  {'id': '1ayzyQxMlOZy8KNcHo67tQ',
#   'name': 'Quesabrosa',
#   'review_count': 151,
#   'category': 'Mexican',
#   'rating': 4.0,
#   'price': '$',
#   'city': 'Portland',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.5517566,
#   'Lng': -122.6663433},
#  {'id': '0Eb3tKtnNHxrryfxPm1yOA',
#   'name': 'La Arepa',
#   'review_count': 89,
#   'category': 'Other',
#   'rating': 4.5,
#   'price': '$',
#   'city': 'Portland',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.5339056162549,
#   'Lng': -122.601317167282},
#  {'id': 'qhfcNOgoSsXeN8heOh8TaQ',
#   'name': 'Si Senor Cedar Mill',
#   'review_count': 238,
#   'category': 'Mexican',
#   'rating': 3.5,
#   'price': '$$',
#   'city': 'Portland',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.5163250229241,
#   'Lng': -122.795860044793},
#  {'id': 'AnWJSOzOZmSmhbauj0_d4Q',
#   'name': 'Gather Food & Drink',
#   'review_count': 83,
#   'category': 'Other',
#   'rating': 3.5,
#   'price': '$$',
#   'city': 'Portland',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.530775,
#   'Lng': -122.655565},
#  {'id': 'kqzI14xOCHJC0qXw8JyS0Q',
#   'name': "Matt's BBQ",
#   'review_count': 578,
#   'category': 'Other',
#   'rating': 4.5,
#   'price': '$$',
#   'city': 'Portland',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.5543767514692,
#   'Lng': -122.675831279762},
#  {'id': 'OLVYtoZDFn95LwXzceYysw',
#   'name': 'Nuevo Vallarta',
#   'review_count': 70,
#   'category': 'Mexican',
#   'rating': 3.5,
#   'price': '$$',
#   'city': 'Canby',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.2675399,
#   'Lng': -122.67792},
#  {'id': 'giLX7ndl5XYIjq6o0AAMpA',
#   'name': 'Victoria',
#   'review_count': 240,
#   'category': 'Other',
#   'rating': 4.0,
#   'price': '$$',
#   'city': 'Portland',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.558034,
#   'Lng': -122.675259},
#  {'id': 'lMvAqE8YvLTW91-CWVy9Zw',
#   'name': 'Casa Colima Mexican Restaurant - Tualatin',
#   'review_count': 100,
#   'category': 'Mexican',
#   'rating': 3.5,
#   'price': '$$',
#   'city': 'Tualatin',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.39032,
#   'Lng': -122.80449},
#  {'id': 'XLGYNoaTw29haNDRpcNE0A',
#   'name': 'Los 2 Agaves',
#   'review_count': 96,
#   'category': 'Mexican',
#   'rating': 4.0,
#   'price': '$$',
#   'city': 'Canby',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.263211,
#   'Lng': -122.692557},
#  {'id': 'huveiOZFjsFI_Aiq9Sxs3w',
#   'name': 'Catedral Tapatia',
#   'review_count': 196,
#   'category': 'Mexican',
#   'rating': 3.0,
#   'price': '$$',
#   'city': 'Vancouver',
#   'state': 'WA',
#   'country': 'US',
#   'Lat': 45.61628,
#   'Lng': -122.50376},
#  {'id': 'vj4tc3UWl8qeGMVE457X8g',
#   'name': 'El Rancho Viejo',
#   'review_count': 143,
#   'category': 'Mexican',
#   'rating': 4.0,
#   'price': '$$',
#   'city': 'Battle Ground',
#   'state': 'WA',
#   'country': 'US',
#   'Lat': 45.78062,
#   'Lng': -122.53794},
#  {'id': 'BkLYIaVW2UlX6Td_r-J6nw',
#   'name': 'La Costita Mexican Restaurant',
#   'review_count': 197,
#   'category': 'Mexican',
#   'rating': 3.0,
#   'price': '$$',
#   'city': 'Clackamas',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.4239714451145,
#   'Lng': -122.513136264992},
#  {'id': 'bzSvS_VSPFeArZAKK1Mofw',
#   'name': 'La Quebrada Taqueria',
#   'review_count': 46,
#   'category': 'Mexican',
#   'rating': 4.0,
#   'price': '$',
#   'city': 'Portland',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.609873,
#   'Lng': -122.677043},
#  {'id': '-921gYzvMFJmxJw9SMZ5mA',
#   'name': 'Sanchez Taquería',
#   'review_count': 363,
#   'category': 'Mexican',
#   'rating': 4.0,
#   'price': '$$',
#   'city': 'Tigard',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.42544,
#   'Lng': -122.77993},
#  {'id': 'DrR9pKV1dXoHNOx_YvH6qg',
#   'name': 'Los Potrillos Mexican Restaurant',
#   'review_count': 179,
#   'category': 'Mexican',
#   'rating': 3.0,
#   'price': '$$',
#   'city': 'Camas',
#   'state': 'WA',
#   'country': 'US',
#   'Lat': 45.6092529296875,
#   'Lng': -122.475463867188},
#  {'id': 'L4ZI6fW2PfiXfhJ5sI9Kbw',
#   'name': 'Departure Restaurant + Lounge',
#   'review_count': 1689,
#   'category': 'Other',
#   'rating': 3.5,
#   'price': '$$$',
#   'city': 'Portland',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.518944,
#   'Lng': -122.677798},
#  {'id': '0jlUpkdXg3LCE44UKKhjqA',
#   'name': 'Portland City Grill',
#   'review_count': 3283,
#   'category': 'Other',
#   'rating': 4.0,
#   'price': '$$$',
#   'city': 'Portland',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.52221645834491,
#   'Lng': -122.67595152525597},
#  {'id': 'SAIXHiySZur4y62otpkcOg',
#   'name': 'Provecho Mexican Grill',
#   'review_count': 281,
#   'category': 'Mexican',
#   'rating': 3.5,
#   'price': '$$',
#   'city': 'Vancouver',
#   'state': 'WA',
#   'country': 'US',
#   'Lat': 45.63514,
#   'Lng': -122.67086},
#  {'id': 'aBrIn3sNfhTuF9kCNOCk6w',
#   'name': 'Don Asado',
#   'review_count': 222,
#   'category': 'Other',
#   'rating': 4.5,
#   'price': '$$',
#   'city': 'Aloha',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.495333640775755,
#   'Lng': -122.86631447055244},
#  {'id': '4OXL6Uw-dNSqBtt2gz3dQA',
#   'name': 'Manzanillo Mexican Restaurant',
#   'review_count': 58,
#   'category': 'Mexican',
#   'rating': 3.0,
#   'price': '$$',
#   'city': 'Sherwood',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.36866,
#   'Lng': -122.84708},
#  {'id': 's8yFdlU3egvZZ11--LdEcQ',
#   'name': "Amalfi's Restaurant & Mercato",
#   'review_count': 408,
#   'category': 'Italian',
#   'rating': 3.5,
#   'price': '$$',
#   'city': 'Portland',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.5485038757324,
#   'Lng': -122.614730834961},
#  {'id': '6tsGC9lrOQ3sPk6-YDa_Ng',
#   'name': 'Casa Italia On Division',
#   'review_count': 383,
#   'category': 'Italian',
#   'rating': 4.5,
#   'price': '$$',
#   'city': 'Portland',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.505024,
#   'Lng': -122.633946},
#  {'id': 'HWC1BzoQrga6VS_FffQRZg',
#   'name': 'Margarita Factory - Gresham',
#   'review_count': 416,
#   'category': 'Mexican',
#   'rating': 3.5,
#   'price': '$$',
#   'city': 'Gresham',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.5005,
#   'Lng': -122.42997},
#  {'id': 'jCy-3qRF0t5XGX36JPOvFA',
#   'name': 'Cha Cha Cha Taqueria',
#   'review_count': 216,
#   'category': 'Mexican',
#   'rating': 3.0,
#   'price': '$',
#   'city': 'Portland',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.5352958240087,
#   'Lng': -122.638246184374},
#  {'id': 'YYrk1Yn5POGfJC03nIxHgQ',
#   'name': 'Villa Angel Taquería',
#   'review_count': 26,
#   'category': 'Mexican',
#   'rating': 4.5,
#   'price': '$',
#   'city': 'Portland',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.52228,
#   'Lng': -122.67911},
#  {'id': '_7NZ6GKIPyGoemq7_uaDuA',
#   'name': 'Agave Azul',
#   'review_count': 288,
#   'category': 'Mexican',
#   'rating': 4.0,
#   'price': '$$',
#   'city': 'Gresham',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.49724,
#   'Lng': -122.41672},
#  {'id': 'RgtHHCO5734yNDM0N9h22Q',
#   'name': 'La Sirenita 2',
#   'review_count': 178,
#   'category': 'Mexican',
#   'rating': 4.0,
#   'price': '$',
#   'city': 'Portland',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.46525,
#   'Lng': -122.64724},
#  {'id': 'rUS5vvSNnuOiBX52NUhowg',
#   'name': 'Verde Cocina',
#   'review_count': 172,
#   'category': 'Mexican',
#   'rating': 3.5,
#   'price': '$$',
#   'city': 'Portland',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.50954,
#   'Lng': -122.73438},
#  {'id': 'f7fKR7nP1Bmj1U9_oWUASg',
#   'name': 'OC Taco',
#   'review_count': 99,
#   'category': 'Other',
#   'rating': 4.5,
#   'price': '$$',
#   'city': 'Oregon City',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.36047,
#   'Lng': -122.60314},
#  {'id': 'Mf9io8WkMyGautXuSSfGTg',
#   'name': 'Los Potrillos Mexican Restaurant & Bar',
#   'review_count': 107,
#   'category': 'Mexican',
#   'rating': 3.5,
#   'price': '$$',
#   'city': 'Vancouver',
#   'state': 'WA',
#   'country': 'US',
#   'Lat': 45.6988889,
#   'Lng': -122.703543},
#  {'id': 'ENwBByjpoa5Gg7tKgxqwLg',
#   'name': "Javier's Taco Shop",
#   'review_count': 288,
#   'category': 'Mexican',
#   'rating': 3.0,
#   'price': '$',
#   'city': 'Portland',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.57746,
#   'Lng': -122.66809},
#  {'id': 'eaot-BCBn2SVgdxyATckVg',
#   'name': 'Jo Bar & Rotisserie',
#   'review_count': 260,
#   'category': 'Other',
#   'rating': 4.0,
#   'price': '$$',
#   'city': 'Portland',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.52787,
#   'Lng': -122.69876},
#  {'id': 'UwKwzfJ5M7aEvu5zLPQ9VA',
#   'name': 'Mi Pueblo Mexican Restaurant',
#   'review_count': 316,
#   'category': 'Mexican',
#   'rating': 4.0,
#   'price': '$$',
#   'city': 'Portland',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.446794,
#   'Lng': -122.579874},
#  {'id': '06SZFxTJpq2hTy5FsDvYSA',
#   'name': 'La Fiesta Mexican Kitchen & Tequila Bar',
#   'review_count': 238,
#   'category': 'Mexican',
#   'rating': 3.5,
#   'price': '$$',
#   'city': 'West Linn',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.344,
#   'Lng': -122.65475},
#  {'id': 'C2kDo2CFGP_0073dgMmZNw',
#   'name': 'Taco Pedaler',
#   'review_count': 275,
#   'category': 'Other',
#   'rating': 3.5,
#   'price': '$',
#   'city': 'Portland',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.53524,
#   'Lng': -122.64238},
#  {'id': 'IBtiaOtA47ZVuojFI5Xueg',
#   'name': "Sandoval's Cafe & Cantina",
#   'review_count': 216,
#   'category': 'Mexican',
#   'rating': 3.5,
#   'price': '$$',
#   'city': 'Portland',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.51628,
#   'Lng': -122.75346},
#  {'id': 'uvp6ZFzGCXgAVuCP2TSjDQ',
#   'name': 'Angel Food & Fun',
#   'review_count': 186,
#   'category': 'Mexican',
#   'rating': 4.5,
#   'price': '$',
#   'city': 'Portland',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.5601,
#   'Lng': -122.60109},
#  {'id': 'LmsoIaPNsBhaQ4yXWJPHvw',
#   'name': "El Indio's",
#   'review_count': 48,
#   'category': 'Mexican',
#   'rating': 3.0,
#   'price': '$$',
#   'city': 'Portland',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.51869,
#   'Lng': -122.46313},
#  {'id': 'ms1iBCtAhu4QupXY-uFp4A',
#   'name': "Don Pepe's Fresh Mexican Food",
#   'review_count': 284,
#   'category': 'Mexican',
#   'rating': 4.0,
#   'price': '$$',
#   'city': 'Oregon City',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.35808,
#   'Lng': -122.60832},
#  {'id': '7_MfaTOxYy4CgkVyX0sJPw',
#   'name': 'Han Oak',
#   'review_count': 313,
#   'category': 'Other',
#   'rating': 4.0,
#   'price': '$$$$',
#   'city': 'Portland',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.5267944137298,
#   'Lng': -122.641767226159},
#  {'id': 'DNWZ3ovlCrle-P8RDKMYBQ',
#   'name': 'Mi Jalisco Family Mexican Restaurant',
#   'review_count': 153,
#   'category': 'Mexican',
#   'rating': 4.0,
#   'price': '$$',
#   'city': 'Aloha',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.4796832,
#   'Lng': -122.860027},
#  {'id': 'zJMQULXQrZGJG-x9RyuSrQ',
#   'name': "Small Pharoah's",
#   'review_count': 257,
#   'category': 'Other',
#   'rating': 4.0,
#   'price': '$',
#   'city': 'Portland',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.52087473589821,
#   'Lng': -122.67633519573478},
#  {'id': 'lk_Pf67uaChin59jhW9F1g',
#   'name': 'Tight Tacos',
#   'review_count': 138,
#   'category': 'Mexican',
#   'rating': 4.0,
#   'price': '$',
#   'city': 'Portland',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.5046535,
#   'Lng': -122.6340244},
#  {'id': 'Ys42wLKqrflqmtqkgqOXgA',
#   'name': 'Luc Lac',
#   'review_count': 3944,
#   'category': 'Other',
#   'rating': 4.0,
#   'price': '$$',
#   'city': 'Portland',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.516868,
#   'Lng': -122.675447},
#  {'id': 'Jh4Z7pUEeyoKacmRrYgNIA',
#   'name': 'La Jarochita',
#   'review_count': 231,
#   'category': 'Mexican',
#   'rating': 4.0,
#   'price': '$',
#   'city': 'Portland',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.521303280283334,
#   'Lng': -122.676075},
#  {'id': 'G2Q3ukeP3AX_DBfZuKyl3w',
#   'name': 'Taquería El Cazador',
#   'review_count': 118,
#   'category': 'Mexican',
#   'rating': 4.0,
#   'price': '$',
#   'city': 'Portland',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.47740520000001,
#   'Lng': -122.5588671},
#  {'id': 'DtHsu_dWcgVkcaifLPxnlA',
#   'name': 'Los Temos Taqueria Milwaukie',
#   'review_count': 40,
#   'category': 'Mexican',
#   'rating': 4.0,
#   'price': '$',
#   'city': 'Portland',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.3985672,
#   'Lng': -122.618309},
#  {'id': 'pNT9yivSNb4BlPGI9kr2aA',
#   'name': 'Habaneros Mexican Food',
#   'review_count': 191,
#   'category': 'Mexican',
#   'rating': 2.5,
#   'price': '$',
#   'city': 'Portland',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.53456,
#   'Lng': -122.65827},
#  {'id': '-0Xp38z1AEfUm35gJ-6b2Q',
#   'name': 'El Chilito',
#   'review_count': 141,
#   'category': 'Mexican',
#   'rating': 4.5,
#   'price': '$',
#   'city': 'Canby',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.26068,
#   'Lng': -122.69592},
#  {'id': 'n7oPfCzrFTwcuDc8qtjH2w',
#   'name': 'Mazatlan Mexican Restaurant',
#   'review_count': 87,
#   'category': 'Mexican',
#   'rating': 3.5,
#   'price': '$$',
#   'city': 'Sherwood',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.3697853069047,
#   'Lng': -122.842319011688},
#  {'id': 'xOr2jdTnIRFK-ou3WaK7Rw',
#   'name': 'Lima Peruvian Restaurant',
#   'review_count': 339,
#   'category': 'Other',
#   'rating': 4.5,
#   'price': '$$',
#   'city': 'Beaverton',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.476231,
#   'Lng': -122.801482},
#  {'id': 'GLoFtiApGbbYZ8-ytJHqTw',
#   'name': 'Salt & Pepper',
#   'review_count': 58,
#   'category': 'Mexican',
#   'rating': 4.5,
#   'price': '$$',
#   'city': 'Portland',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.49745,
#   'Lng': -122.59389},
#  {'id': 'yqfkFLG7PYYsB0tjjp7hYg',
#   'name': 'Los Dos Compadres Cantina',
#   'review_count': 57,
#   'category': 'Mexican',
#   'rating': 3.5,
#   'price': '$$',
#   'city': 'Washougal',
#   'state': 'WA',
#   'country': 'US',
#   'Lat': 45.581378,
#   'Lng': -122.353187},
#  {'id': 'K_bYrQf2lIm7ZsrJxf5EXg',
#   'name': 'Casa Del Sol',
#   'review_count': 86,
#   'category': 'Mexican',
#   'rating': 4.0,
#   'price': '$',
#   'city': 'Clackamas',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.4123919,
#   'Lng': -122.5683938},
#  {'id': 'B-CVEjoMUn4nVHZ897aHvw',
#   'name': 'La Mixteca Oaxaca',
#   'review_count': 41,
#   'category': 'Mexican',
#   'rating': 4.0,
#   'price': '$$',
#   'city': 'Hillsboro',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.51693,
#   'Lng': -122.972793},
#  {'id': 'L7LYQ2q_KtQpSzuWYlx2TQ',
#   'name': 'Petisco',
#   'review_count': 389,
#   'category': 'Other',
#   'rating': 4.5,
#   'price': '$$',
#   'city': 'Portland',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.53527,
#   'Lng': -122.6511},
#  {'id': 'PZHInbhr513et4rVer70dw',
#   'name': 'Jade Bistro Teahouse & Patisserie',
#   'review_count': 986,
#   'category': 'Thai',
#   'rating': 4.0,
#   'price': '$$',
#   'city': 'Portland',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.466892,
#   'Lng': -122.652683},
#  {'id': 'yedm3nPJr936ssEvzNabfw',
#   'name': "Maya's Taqueria",
#   'review_count': 356,
#   'category': 'Mexican',
#   'rating': 3.5,
#   'price': '$',
#   'city': 'Portland',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.5200152844191,
#   'Lng': -122.682325914502},
#  {'id': 'TtyBItYez5xct5gfwIT5_Q',
#   'name': 'Korita Sabor Casero',
#   'review_count': 62,
#   'category': 'Mexican',
#   'rating': 5.0,
#   'price': '$',
#   'city': 'Portland',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.58086824163467,
#   'Lng': -122.65911796105735},
#  {'id': 'mqHgh2t0zYXR57Ee3I6tgQ',
#   'name': 'El Grullense',
#   'review_count': 41,
#   'category': 'Mexican',
#   'rating': 5.0,
#   'price': '$',
#   'city': 'Vancouver',
#   'state': 'WA',
#   'country': 'US',
#   'Lat': 45.678374,
#   'Lng': -122.626068},
#  {'id': 'di6_pQedsj01pAiUIJ9xaQ',
#   'name': 'Tienda Santa Cruz',
#   'review_count': 109,
#   'category': 'Mexican',
#   'rating': 4.5,
#   'price': '$',
#   'city': 'Portland',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.522374680550065,
#   'Lng': -122.5787259},
#  {'id': '3-IPSCFRlGX_mFcNhGqL0Q',
#   'name': 'Don Pedro',
#   'review_count': 148,
#   'category': 'Mexican',
#   'rating': 4.0,
#   'price': '$',
#   'city': 'Portland',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.4866142272949,
#   'Lng': -122.731506347656},
#  {'id': 'iwYO3HNR1gefE_6vwfmlkw',
#   'name': 'Los Dos Compadres',
#   'review_count': 75,
#   'category': 'Mexican',
#   'rating': 4.0,
# ...
#   'review_count': 205,
#   'category': 'Italian',
#   'rating': 4.0,
#   'price': '$$',
#   'city': 'Beaverton',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.53660318164761,
#   'Lng': -122.8637373705575},
#  {'id': 'dOvapKIr5NUIuQ3d6VaB5w',
#   'name': 'Pastini',
#   'review_count': 257,
#   'category': 'Italian',
#   'rating': 4.0,
#   'price': '$$',
#   'city': 'Portland',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.5048271,
#   'Lng': -122.6449549},
#  {'id': '9VaPtJVziILHr4ghXfzuSw',
#   'name': 'The Pocket Pub',
#   'review_count': 175,
#   'category': 'Other',
#   'rating': 4.5,
#   'price': '$$',
#   'city': 'Portland',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.54236,
#   'Lng': -122.65894},
#  {'id': '5ZZnsolkH4bQsxRx7Tcpuw',
#   'name': 'Carina Lounge',
#   'review_count': 196,
#   'category': 'Other',
#   'rating': 4.5,
#   'price': '$$',
#   'city': 'Portland',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.52581,
#   'Lng': -122.69408},
#  {'id': 'KViMfhnwAlS--FCFunaVwg',
#   'name': "Salty's on the Columbia River",
#   'review_count': 1528,
#   'category': 'Other',
#   'rating': 4.0,
#   'price': '$$$',
#   'city': 'Portland',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.601008,
#   'Lng': -122.624584},
#  {'id': 'Uka2rQrKf2dS6AhRUKwzrw',
#   'name': 'Stormbreaker Brewing',
#   'review_count': 414,
#   'category': 'Other',
#   'rating': 4.0,
#   'price': '$$',
#   'city': 'Portland',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.54943,
#   'Lng': -122.675156},
#  {'id': 'ZC3ZDGsQQKSLzQPV1OMMkw',
#   'name': 'Pastini',
#   'review_count': 340,
#   'category': 'Italian',
#   'rating': 3.5,
#   'price': '$$',
#   'city': 'Beaverton',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.4946790491456,
#   'Lng': -122.81176639050771},
#  {'id': 'cvLkq3hxRKH--995r1gv4A',
#   'name': 'Mediterranean Exploration Company',
#   'review_count': 922,
#   'category': 'Other',
#   'rating': 4.5,
#   'price': '$$',
#   'city': 'Portland',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.5255436459797,
#   'Lng': -122.684474076721},
#  {'id': 'mNNAw7dv4ZppIyI3Povang',
#   'name': 'Tastebud',
#   'review_count': 248,
#   'category': 'Other',
#   'rating': 4.0,
#   'price': '$$',
#   'city': 'Portland',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.4683599,
#   'Lng': -122.7125893},
#  {'id': 'DaW_u2aIfhvL9Tx5wDMKUA',
#   'name': 'Vino Volo',
#   'review_count': 40,
#   'category': 'Other',
#   'rating': 4.5,
#   'price': '$$',
#   'city': 'Portland',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.589217,
#   'Lng': -122.5934769},
#  {'id': 'RizNVhPsFQUIU4gwFZfQQA',
#   'name': 'Caro Amico Italian Cafe',
#   'review_count': 171,
#   'category': 'Italian',
#   'rating': 4.0,
#   'price': '$$',
#   'city': 'Portland',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.497123,
#   'Lng': -122.67853},
#  {'id': '43PU7kmd2jxAWKy_DP9D7g',
#   'name': 'Sweet Hereafter',
#   'review_count': 486,
#   'category': 'Other',
#   'rating': 4.0,
#   'price': '$$',
#   'city': 'Portland',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.516372,
#   'Lng': -122.6303344},
#  {'id': 'G-ix5jvYyMRUu6tcUIJCCg',
#   'name': 'Bible Club',
#   'review_count': 287,
#   'category': 'Other',
#   'rating': 4.5,
#   'price': '$$',
#   'city': 'Portland',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.4740967378096,
#   'Lng': -122.649830617011},
#  {'id': 'RUlz2QsvsmBnO4FzcS747Q',
#   'name': 'Nebbiolo Restaurant & Wine Bar',
#   'review_count': 225,
#   'category': 'Other',
#   'rating': 4.5,
#   'price': '$$',
#   'city': 'Oregon City',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.35828,
#   'Lng': -122.60717},
#  {'id': 'pgJKFMMJvCHJEpSzvdtC6Q',
#   'name': '24th Pizza & Meatballs',
#   'review_count': 341,
#   'category': 'Italian',
#   'rating': 4.0,
#   'price': '$$',
#   'city': 'Portland',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.5266075134277,
#   'Lng': -122.641616821289},
#  {'id': 'AhhY8VzZAcbpmu8ZqrlsVQ',
#   'name': 'Lardo',
#   'review_count': 1336,
#   'category': 'Other',
#   'rating': 4.0,
#   'price': '$$',
#   'city': 'Portland',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.512166,
#   'Lng': -122.653066},
#  {'id': 'qojgbIgr7rcBZ5OZcZswnQ',
#   'name': 'The Dundee Bistro',
#   'review_count': 363,
#   'category': 'Italian',
#   'rating': 3.5,
#   'price': '$$$',
#   'city': 'Dundee',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.27834,
#   'Lng': -123.01114},
#  {'id': '39DCSovdB48QjQYQlkD3gQ',
#   'name': "Bugatti's - Oregon City",
#   'review_count': 262,
#   'category': 'Italian',
#   'rating': 3.5,
#   'price': '$$',
#   'city': 'Oregon City',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.3362814,
#   'Lng': -122.5931784},
#  {'id': 'DrOFKVAPaZjZXdG0Or77mA',
#   'name': 'Papa Haydn - Sellwood',
#   'review_count': 494,
#   'category': 'Other',
#   'rating': 4.0,
#   'price': '$$$',
#   'city': 'Portland',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.4802899,
#   'Lng': -122.64983},
#  {'id': 'vUteYFB9WGCei_onyTpm4g',
#   'name': 'Mi Cava & Cocina',
#   'review_count': 104,
#   'category': 'Mexican',
#   'rating': 4.0,
#   'price': '$$',
#   'city': 'Portland',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.51723,
#   'Lng': -122.56305},
#  {'id': '-5-s0IGhN633QhhS_TSR9A',
#   'name': 'The Old Spaghetti Factory',
#   'review_count': 450,
#   'category': 'Italian',
#   'rating': 3.0,
#   'price': '$$',
#   'city': 'Portland',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.493338,
#   'Lng': -122.669385},
#  {'id': 'XrwHLWUx3bvQ_jZVanTc2Q',
#   'name': 'Interurban',
#   'review_count': 547,
#   'category': 'Other',
#   'rating': 4.0,
#   'price': '$$',
#   'city': 'Portland',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.5529720703346,
#   'Lng': -122.67572524184303},
#  {'id': 'hBupgpEHfCQG2fXslQfDhw',
#   'name': 'Pastini',
#   'review_count': 341,
#   'category': 'Italian',
#   'rating': 4.0,
#   'price': '$$',
#   'city': 'Tigard',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.3969556667888,
#   'Lng': -122.751192940552},
#  {'id': 'CoZbETgq7mF5JzzxLMeF6Q',
#   'name': 'Via Chicago',
#   'review_count': 365,
#   'category': 'Other',
#   'rating': 4.0,
#   'price': '$$',
#   'city': 'Portland',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.55929,
#   'Lng': -122.64444},
#  {'id': 'VEBfMPm0t1nimHOAXuMvrg',
#   'name': 'Verde Cocina en la Perla',
#   'review_count': 80,
#   'category': 'Mexican',
#   'rating': 4.0,
#   'price': '$$',
#   'city': 'Portland',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.527314,
#   'Lng': -122.683124},
#  {'id': 'Ys42wLKqrflqmtqkgqOXgA',
#   'name': 'Luc Lac',
#   'review_count': 3944,
#   'category': 'Other',
#   'rating': 4.0,
#   'price': '$$',
#   'city': 'Portland',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.516868,
#   'Lng': -122.675447},
#  {'id': 'pj8yEXVlwjXW95J26aX07w',
#   'name': 'Rovente Pizzeria',
#   'review_count': 66,
#   'category': 'Italian',
#   'rating': 4.5,
#   'price': '$',
#   'city': 'Portland',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.55514,
#   'Lng': -122.66711},
#  {'id': 'DE1_PCuMfpUHd7SV-q4lTw',
#   'name': 'SubTerra Kitchen & Cellar',
#   'review_count': 261,
#   'category': 'Other',
#   'rating': 4.0,
#   'price': '$$',
#   'city': 'Newberg',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.30127179999999,
#   'Lng': -122.9641562},
#  {'id': 'JnLtY1aww2qbPlrbRDQo7Q',
#   'name': "Gustav's Pub & Grill",
#   'review_count': 358,
#   'category': 'Other',
#   'rating': 3.5,
#   'price': '$$',
#   'city': 'Vancouver',
#   'state': 'WA',
#   'country': 'US',
#   'Lat': 45.6079406738281,
#   'Lng': -122.503425598145},
#  {'id': 'k-UzVF9bUZN9ZlZt-vnFeQ',
#   'name': 'Grassa',
#   'review_count': 51,
#   'category': 'Italian',
#   'rating': 4.0,
#   'price': '$$',
#   'city': 'Vancouver',
#   'state': 'WA',
#   'country': 'US',
#   'Lat': 45.6242069,
#   'Lng': -122.6800958},
#  {'id': 'YI4Lnn_yhP6E_S2z6BOI_w',
#   'name': 'Pizzeria Otto FoPo',
#   'review_count': 97,
#   'category': 'Italian',
#   'rating': 4.0,
#   'price': '$$',
#   'city': 'Portland',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.486678,
#   'Lng': -122.590087},
#  {'id': 'vFRX585yAlTuPNVZniHwEw',
#   'name': "Clyde's Prime Rib Restaurant & Bar",
#   'review_count': 560,
#   'category': 'Other',
#   'rating': 3.5,
#   'price': '$$',
#   'city': 'Portland',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.541204181439845,
#   'Lng': -122.60630454583773},
#  {'id': 'g0BfjSHuXWvsv-aKU4RHfw',
#   'name': 'Oven and Shaker - Lake Oswego',
#   'review_count': 48,
#   'category': 'Other',
#   'rating': 4.0,
#   'price': '$$',
#   'city': 'Lake Oswego',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.41501363461534,
#   'Lng': -122.71694153147885},
#  {'id': 'pW5P97D8CnQTv1gLXwkpTA',
#   'name': 'Mississippi Pizza Pub & Atlantis Lounge',
#   'review_count': 474,
#   'category': 'Other',
#   'rating': 4.0,
#   'price': '$',
#   'city': 'Portland',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.5486099,
#   'Lng': -122.67524},
#  {'id': 'kn1I-YXK40V4uD6hcM-GLw',
#   'name': 'Sapphire Hotel',
#   'review_count': 485,
#   'category': 'Other',
#   'rating': 4.5,
#   'price': '$$',
#   'city': 'Portland',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.51175,
#   'Lng': -122.61132},
#  {'id': 'eTjaXgajoYKVt-O3FRlyaA',
#   'name': 'The Old Spaghetti Factory',
#   'review_count': 212,
#   'category': 'Italian',
#   'rating': 3.0,
#   'price': '$$',
#   'city': 'Vancouver',
#   'state': 'WA',
#   'country': 'US',
#   'Lat': 45.61622432,
#   'Lng': -122.5079404},
#  {'id': 'VB1HluH8vNIV0-l0CyPSeQ',
#   'name': 'Davenport',
#   'review_count': 162,
#   'category': 'Other',
#   'rating': 4.0,
#   'price': '$$$',
#   'city': 'Portland',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.5229857,
#   'Lng': -122.6431129},
#  {'id': '1jU-vzsDTWLNUT7R-fjNzg',
#   'name': 'Arrowood',
#   'review_count': 95,
#   'category': 'Other',
#   'rating': 4.5,
#   'price': '$$',
#   'city': 'Portland',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.54277,
#   'Lng': -122.6028},
#  {'id': 'jjZXY-WwV6oWDQSnKM8irA',
#   'name': 'Allium',
#   'review_count': 240,
#   'category': 'Other',
#   'rating': 4.0,
#   'price': '$$',
#   'city': 'West Linn',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.3449,
#   'Lng': -122.65407},
#  {'id': 'ouXAmnaDtkIRKynIvmkzjg',
#   'name': "Bugatti's Ristorante",
#   'review_count': 200,
#   'category': 'Italian',
#   'rating': 3.5,
#   'price': '$$',
#   'city': 'West Linn',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.390336,
#   'Lng': -122.644651},
#  {'id': 'XsHQALkQs9DnahEe-aBW1A',
#   'name': 'Forage',
#   'review_count': 39,
#   'category': 'Other',
#   'rating': 4.5,
#   'price': '$$',
#   'city': 'Newberg',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.30020142533898,
#   'Lng': -122.980753892626},
#  {'id': '6PKLpJqyf6B9ZI-RkDM6IA',
#   'name': 'The Muddy Rudder Public House',
#   'review_count': 218,
#   'category': 'Other',
#   'rating': 4.0,
#   'price': '$$',
#   'city': 'Portland',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.4641723632812,
#   'Lng': -122.659309387207},
#  {'id': 'Gu3iogPmH1_6VqRByV3ITA',
#   'name': 'Salud Wine Bar, Italian Dining And Wine Storage',
#   'review_count': 74,
#   'category': 'Italian',
#   'rating': 4.0,
#   'price': '$$',
#   'city': 'Camas',
#   'state': 'WA',
#   'country': 'US',
#   'Lat': 45.58441,
#   'Lng': -122.40448},
#  {'id': 'Ql8BrqRcvm5Yqyg-pEQ0Vw',
#   'name': "The Lounge At Gilda's",
#   'review_count': 18,
#   'category': 'Italian',
#   'rating': 4.0,
#   'price': '$$',
#   'city': 'Portland',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.5217419564724,
#   'Lng': -122.688309252262},
#  {'id': 'xOr2jdTnIRFK-ou3WaK7Rw',
#   'name': 'Lima Peruvian Restaurant',
#   'review_count': 339,
#   'category': 'Other',
#   'rating': 4.5,
#   'price': '$$',
#   'city': 'Beaverton',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.476231,
#   'Lng': -122.801482},
#  {'id': 'URr8tsxfK0bSaC01VGr3-Q',
#   'name': 'Bacchus Bar',
#   'review_count': 33,
#   'category': 'Other',
#   'rating': 4.0,
#   'price': '$$',
#   'city': 'Portland',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.520897,
#   'Lng': -122.678536},
#  {'id': '21SyD7A2C65etBf4tZZVLg',
#   'name': 'The Westgate Bourbon Bar & Taphouse',
#   'review_count': 766,
#   'category': 'Other',
#   'rating': 4.0,
#   'price': '$$',
#   'city': 'Beaverton',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.4918468,
#   'Lng': -122.8100733},
#  {'id': 'b18xKre4abQNSOsamOxuaA',
#   'name': 'Teardrop Cocktail Lounge',
#   'review_count': 900,
#   'category': 'Other',
#   'rating': 4.5,
#   'price': '$$',
#   'city': 'Portland',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.525217429293,
#   'Lng': -122.68164173744},
#  {'id': 'oVOFZTfnmHmZz3IJ3uy1fQ',
#   'name': 'Olympia Provisions',
#   'review_count': 1076,
#   'category': 'Other',
#   'rating': 4.5,
#   'price': '$$',
#   'city': 'Portland',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.5190372372082,
#   'Lng': -122.664292728836},
#  {'id': 'iaOWsQlhHTkHMTThpB1UNQ',
#   'name': 'Apizza Scholls',
#   'review_count': 1710,
#   'category': 'Other',
#   'rating': 4.0,
#   'price': '$$',
#   'city': 'Portland',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.512127,
#   'Lng': -122.613131},
#  {'id': 'PZHInbhr513et4rVer70dw',
#   'name': 'Jade Bistro Teahouse & Patisserie',
#   'review_count': 986,
#   'category': 'Thai',
#   'rating': 4.0,
#   'price': '$$',
#   'city': 'Portland',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.466892,
#   'Lng': -122.652683},
#  {'id': 'lBRlHsXgBwWszAaVcV6dYg',
#   'name': 'Sizzle Pie',
#   'review_count': 1095,
#   'category': 'Italian',
#   'rating': 4.0,
#   'price': '$',
#   'city': 'Portland',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.5227460279759,
#   'Lng': -122.659085913643},
#  {'id': '7ksrUwDaTTZcKOWfFrbxLA',
#   'name': 'The Painted Lady',
#   'review_count': 257,
#   'category': 'Other',
#   'rating': 4.5,
#   'price': '$$$$',
#   'city': 'Newberg',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.29931,
#   'Lng': -122.97312},
#  {'id': 'ZqZuJRA1ok7E10CqYrS7Nw',
#   'name': 'Ooh, Pasta!',
#   'review_count': 109,
#   'category': 'Italian',
#   'rating': 4.5,
#   'price': '$',
#   'city': 'Portland',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.4635179,
#   'Lng': -122.5794757},
#  {'id': 'eUbq0uNxRlXQ6sy7phM7yA',
#   'name': 'Lechon',
#   'review_count': 1736,
#   'category': 'Other',
#   'rating': 4.5,
#   'price': '$$$',
#   'city': 'Portland',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.52129,
#   'Lng': -122.67094},
#  {'id': 'bL8RqB4mJvJaVquEV3yeMw',
#   'name': 'MOD Pizza',
#   'review_count': 188,
#   'category': 'Other',
#   'rating': 4.0,
#   'price': '$$',
#   'city': 'Portland',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.51723863093558,
#   'Lng': -122.67518888897229},
#  {'id': 'hMAltOTShLpjjsrnF4PxmA',
#   'name': 'Slow Bar',
#   'review_count': 598,
#   'category': 'Other',
#   'rating': 4.0,
#   'price': '$$',
#   'city': 'Portland',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.5188325855706,
#   'Lng': -122.661009026489},
#  {'id': 'lbDumHm4Ot7aa8cSuzwwUA',
#   'name': "Pinky's Pizza",
#   'review_count': 279,
#   'category': 'Other',
#   'rating': 4.5,
#   'price': '$$',
#   'city': 'Portland',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.55197,
#   'Lng': -122.68067},
#  {'id': '6GmUVd6ZD7L8weD5dV1g3Q',
#   'name': 'St. Jack',
#   'review_count': 388,
#   'category': 'Other',
#   'rating': 4.0,
#   'price': '$$$',
#   'city': 'Portland',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.534235,
#   'Lng': -122.698653},
#  {'id': '--UNNdnHRhsyFUbDgumdtQ',
#   'name': 'Le Pigeon',
#   'review_count': 1307,
#   'category': 'Other',
#   'rating': 4.5,
#   'price': '$$$',
#   'city': 'Portland',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.522796,
#   'Lng': -122.657872},
#  {'id': 'oEBHCuZtUpUMVhRrD9afvQ',
#   'name': 'Bella Pizza',
#   'review_count': 237,
#   'category': 'Other',
#   'rating': 4.0,
#   'price': '$$',
#   'city': 'Portland',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.55883,
#   'Lng': -122.63514},
#  {'id': 'y5EOPbtkz7L5lTyX0PX8bA',
#   'name': 'BARba Mingo',
#   'review_count': 196,
#   'category': 'Italian',
#   'rating': 4.5,
#   'price': '$$',
#   'city': 'Portland',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.528861,
#   'Lng': -122.694767},
#  {'id': '0_1g3DSi_dg8qDBXl0UYYA',
#   'name': "Costello's Travel Cafe",
#   'review_count': 293,
#   'category': 'Other',
#   'rating': 4.5,
#   'price': '$$',
#   'city': 'Portland',
#   'state': 'OR',
#   'country': 'US',
#   'Lat': 45.5347786,
#   'Lng': -122.64243},
#  {'id': 'lXk0vXCmJLEvcz1pesPjSw',
#   'name': 'The Sedgwick',
#   'review_count': 99,
#   'category': 'Other',
#   'rating': 4.5,
#   'price': '$$',
#   'city': 'Vancouver',
#   'state': 'WA',
#   'country': 'US',
#   'Lat': 45.62747,
#   'Lng': -122.67249},
#  ...]

# %%
restaurant_data_json = json.dumps(restaurant_data, indent=2)
with open("restaurant_data.json", "w") as outfile:
    outfile.write(restaurant_data_json)

# %%
# Convert the restaurant_data into a Pandas DataFrame
restaurant_data_df = pd.DataFrame(restaurant_data)

# Show Record Count
restaurant_data_df
# Out:
#                           id                    name  review_count category  \
# 0     Vp1kiliceNp6_K8tkRCTCg    La Cocina Restaurant           495  Mexican
# 1     UZUjgF7XW7WkvyUb8_qCiA     Matador NW Portland           871  Mexican
# 2     B0fBpezDvj2Bp-8KOlMMRw          Nuestra Cocina           614  Mexican
# 3     Ir1GUgWHVsXpJeRTfk0HTQ    Carlita's - Portland           223    Other
# 4     4ZPcXpYcmsoiZQGn5M8JuQ    Por Qué No? Taqueria          1312  Mexican
# ...                      ...                     ...           ...      ...
# 2128  mQ5MvO0t62nmrfaxteNQ-A                Pho Viet           152    Other
# 2129  zqDaDcrPJbecQhT4z6okIg  Happy Panda Restaurant           295    Other
# 2130  -MyWfCx-Rk0sZe2N_K9V7w       Noodles & Company            96    Other
# 2131  uwjnnp36-qL8STcdyShMIw       Noodles & Company           154    Other
# 2132  7rkFNmbI2mA_Pa14gfGJfQ            Panera Bread           146    Other
#
#       rating price       city state country        Lat         Lng
# 0        4.0     $   Portland    OR      US  45.550892 -122.667025
# 1        3.5    $$   Portland    OR      US  45.533200 -122.698460
# 2        4.5    $$   Portland    OR      US  45.505030 -122.643790
# 3        4.0    $$   Portland    OR      US  45.531720 -122.682950
# 4        4.0    $$   Portland    OR      US  45.548240 -122.675240
# ...      ...   ...        ...   ...     ...        ...         ...
# 2128     4.0    $$  Hillsboro    OR      US  45.518230 -122.975160
# 2129     3.0    $$  Beaverton    OR      US  45.530197 -122.868965
# 2130     3.5     $  Vancouver    WA      US  45.616399 -122.478121
# 2131     3.0     $  Hillsboro    OR      US  45.538192 -122.904209
# 2132     2.5     $     Tigard    OR      US  45.446369 -122.776767
#
# [2133 rows x 11 columns]

# %%
restaurant_data_df.to_sql('PortlandRestaurants', con=engine)

# %%
from sqlalchemy import text
with engine.connect() as conn:
   conn.execute(text("SELECT * FROM PortlandRestaurants")).fetchall()
